# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера </b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Привет, Роман :) Спасибо, что прислал задание 🤝 Меня зовут Ринат Хисамов и я буду проверять твой проект. Предлагаю обращаться друг к другу на ты. Так нам будет гораздо проще и удобней общаться
#
# Мои комментарии обозначены пометкой <b>Комментарий ревьюера</b>. Далее в файле сможешь найти их в похожих ячейках (если фон комментария зелёный — всё сделано правильно (✔️), рекомендации таким же цветом. Отдельным цветом — блок ссылок (примеры ниже, 🍕). Оранжевым или светло желтым рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше. (⚠️); <u> красный комментарий</u>: код, график или вывод стоит переделать (❌)).
#
# Не удаляй все эти комментарии и постарайся учесть их в ходе выполнения данного проекта.
# Будет замечательно, если добавишь свои комментарии и пояснения✍
#
# __Увидев у тебя неточность, в первый раз я лишь укажу на ее наличие, а ты попробуешь исправить ее самостоятельно. Но если ты пока не справишься с такой задачей — при следующей проверке я дам более подробную подсказку!__
#
# Поехали 🚀
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# <div style="border:solid steelblue 1px; padding: 20px">
#
# <font size="4"><p style="text-align:center"><b>Примеры комментариев </b></p></font>
#
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Пример комментария - совета, здесь м.б. просто ссылка</b></font>
#     <br />
#         <font size="3", color = "black">
# <br />
#     Тут всего такого разного и вкусного :), есть способы прокачать проект визуализациями (ценит большинство "боссов")  <br /><br />
#         <a href="https://devpractice.ru/matplotlib-book/">“Библиотека Matplotlib” доступна для скачивания БЕСПЛАТНО!</a>
#         На сайте много полезных материалов, мне самому очень помогло в свое время, до сих пор подсматриваю :)
#
#
# </div>
#
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
#     <font size="3"><b>⚠️ Пример оформления некритичного комментария</b>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-danger">
# <font size="3"><b>❌ Пример оформления комментария к блоку(строке) программного кода (или выводу), который стоит переделать</b></font>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Отправлен не тот проект, напиши в своих комментариях, что случилось? жду — <b>это пример</b>
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-success">
# <font size="4"><b>✔️ Пример оформления комментария, который нравится большинству студентов</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Круто, молодец, отлично, логично, или — 👌, 👍, или — выводы отвечают на все вопросы к данным и проекту
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# # Для твоих вопросов или комментариев оставлю такую ячейку, чтобы было удобнее взаимодействовать на проекте

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> ... , вот мой вопрос ...

# %% [markdown]
# # Анализ сервиса аренды самокатов GoFast
#
# <span style='font-size: 18px;'>Техническое задание:</span>
#
# В распоряжении данные сервиса аренды самокатов GoFast о некоторых пользователях из нескольких городов, а также об их поездках. Чтобы совершать поездки по городу, пользователи сервиса GoFast пользуются мобильным приложением. Сервисом можно пользоваться без подписки, в таком случае абонентская плата отсутствует, стоимость одной минуты - 8 рублей, стоимость старта поездки - 50 рублей. С подпиской Ultra абонентская плата — 199 рублей в месяц, стоимость одной минуты - 6 рублей, стоимость старта поездки - бесплатно. Продакт-менеджеры сервиса хотят увеличить количество пользователей с подпиской. Необходимо проанализировать данные и проверить некоторые гипотезы, которые могут помочь вырасти бизнесу.
#
# <span style='font-size: 18px;'>План работы:</span>
#
# 1. Изучение общей информации датафреймов:
#     - Пропущенные значения
#     - Неправильные типы данных
#     - Выбросы и аномалии
#     - Явные дубликаты
#
#
# 2. Предобработка данных:
#     - Удаление возможных дубликатов
#     - Изменение типов данных
#     - Добавление номера месяца в датафрейм поездки
#
#
# 3. Исследовательский анализ данных.
#     - Обработка аномальных значений
#     - Описать и визуализировать:
#         - Частоту встречаемости городов
#         - Соотношение пользователей с подпиской и без подписки
#         - Возраст пользователей
#         - Расстояние, которое пользователь преодолел за одну поездку
#         - Продолжительность поездок
#
# 4. Объединение данных:
#     - Обьединение трех таблиц в один датафрейм
#         - Создание двух датафреймов: с подпиской и без
#     - Визуализация информации о расстоянии и времени поездок для пользователей обеих категорий.
#
#
# 5. Подсчёт выручки:
#     - Создать датафрейм с агрегированными данными о поездках на основе датафрейма с объединёнными данными.
#         - Найти для каждого пользователя за каждый месяц:
#             - Суммарное расстояние
#             - Количество поездок
#             - Суммарное время
#     - Добавить столбец с помесячной выручкой, которую принёс каждый пользователь.
#
#
# 6. Проверка гипотез:
#     -  Тратят ли пользователи с подпиской больше времени на поездки?
#     -  Можно ли сказать, что среднее расстояние, которое проезжают пользователи с подпиской за одну поездку, не превышает 3130 метров?
#     -  Будет ли помесячная выручка от пользователей с подпиской по месяцам выше, чем выручка от пользователей без подписки?
#
#
#
#
#
# <span style='font-size: 18px;'>Описание данных:</span>
#
# В основных данных есть информация о пользователях, их поездках и подписках.
#
# 1. Пользователи — users_go:
#     - `user_id` - уникальный идентификатор пользователя
#     - `name` - имя пользователя
#     - `age` - возраст
#     - `city` - город
#     - `subscription_type` - тип подписки (free, ultra)
# 2. Поездки — rides_go:
#     - `user_id` -уникальный идентификатор пользователя
#     - `distance` -расстояние, которое пользователь проехал в текущей сессии (в метрах)
#     - `duration` -продолжительность сессии (в минутах) — время с того момента, как пользователь нажал кнопку «Начать поездку» до момента, как он нажал кнопку «Завершить поездку»
#     - `date` -дата совершения поездки
# 3. Подписки — subscriptions_go:
#     - `subscription_type` - тип подписки
#     - `minute_price` - стоимость одной минуты поездки по данной подписке
#     - `start_ride_price` - стоимость начала поездки
#     - `subscription_fee` - стоимость ежемесячного платежа

# %% [markdown]
# ### 1. Изучение общей информации

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np

# %%
def parse_dataset(path, parse_dates=False):
    try:
        df = pd.read_csv(path, parse_dates=parse_dates)
    except:
        df = pd.read_csv('/'+path, parse_dates=parse_dates)
    
    display(df.head())
    display(df.info())
    print('\nПроцент пропусков')
    display((df.isna().mean()*100).sort_values(ascending=False))
    #print('\nКоличество явных дубликатов:', df[df.duplicated()]['user_id'].count())
    
    return df

# %% [markdown]
# #### 1.1 Датасет пользователи

# %%
user_go = parse_dataset('datasets/users_go.csv')
# Out:
#    user_id        name  age            city subscription_type
# 0        1        Кира   22          Тюмень             ultra
# 1        2   Станислав   31            Омск             ultra
# 2        3     Алексей   20          Москва             ultra
# 3        4  Константин   26  Ростов-на-Дону             ultra
# 4        5       Адель   28            Омск             ultra
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1565 entries, 0 to 1564
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            1565 non-null   int64
#  1   name               1565 non-null   object
#  2   age                1565 non-null   int64
#  3   city               1565 non-null   object
#  4   subscription_type  1565 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 61.3+ KB
# None
# Процент пропусков
# user_id              0.0
# name                 0.0
# age                  0.0
# ...

# %%
plt.title('Гистограмма возраста')
plt.xlabel('Возраст')
plt.ylabel('Количество')
user_go['age'].hist(figsize=(4, 3), bins=50)
plt.show()

# %% [markdown]
# В датасете пользователи отсутствуют пропуски, данные и их типы данных загрузились корректно.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Все  методы можно собрать в функцию и оптимизировать код вывода первичной информации
#
#         def ...:
#             ... dataset.head()
#             ... dataset.info()

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Обзор данных выполнен корректно, применены методы .head() и .info(), промежуточный вывод добавлен, молодец

# %% [markdown]
# #### 1.2 Датасет поездки

# %%
rides_go = parse_dataset('datasets/rides_go.csv', ['date'])
# Out:
#    user_id     distance   duration       date
# 0        1  4409.919140  25.599769 2021-01-01
# 1        1  2617.592153  15.816871 2021-01-18
# 2        1   754.159807   6.232113 2021-04-20
# 3        1  2694.783254  18.511000 2021-08-11
# 4        1  4028.687306  26.265803 2021-08-28
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18068 entries, 0 to 18067
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   18068 non-null  int64
#  1   distance  18068 non-null  float64
#  2   duration  18068 non-null  float64
#  3   date      18068 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(1)
# memory usage: 564.8 KB
# None
# Процент пропусков
# user_id     0.0
# distance    0.0
# duration    0.0
# date        0.0
# dtype: float64

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
#
#
# Если при загрузке данных добавить параметр `parse_dates` то тип данных автоматически переведется в даты. Подробнее про это можно прочитать по ссылке ниже
#
# `parse_dates=['date']`
#
#
#
# https://newtechaudit.ru/gruzi-daty-krasivo/

# %%
rides_go['date'].sort_values()
# Out:
# 0       2021-01-01
# 13113   2021-01-01
# 5445    2021-01-01
# 12775   2021-01-01
# 17096   2021-01-01
#            ...
# 15325   2021-12-30
# 7541    2021-12-30
# 6115    2021-12-30
# 10991   2021-12-30
# 11778   2021-12-30
# Name: date, Length: 18068, dtype: datetime64[ns]

# %%
plt.figure(figsize=(12, 3))

plt.suptitle('Датасет rides_go')

plt.subplot(1,2,1)
plt.title('Гистограмма дистанций')
plt.hist(rides_go['distance'], bins=50)
plt.ylabel('Количество', fontsize=12)
plt.xlabel('Дистанции')
plt.grid()

plt.subplot(1,2,2)
plt.title('Гистограмма продолжительности сессии')
plt.hist(rides_go['duration'], bins=50)
plt.xlabel('Время сессии')
plt.grid()

plt.show()

# %% [markdown]
# В датасете поездки при загрузки данных использовался параметр parse_dates, чтобы дата загрузилась с корректным типом данных. Пропусков в датасете не обнаружено. Данные собраны с 1 января по 30 декабря за 2021 год.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит полностью оформить все графики на проекте
#
# Подписи осей на графиках и название добавят ясности и читабельности.
# Это важные элементы любой визуализации. Как добавить подписи и названия, смотри [здесь](https://proproprogs.ru/modules/matplotlib-razmeshchaem-standartnye-tekstovye-elementy-na-grafike?ysclid=l6agtioc6f299002507)

# %% [markdown]
# #### 1.3 Датасет подписки

# %%
subscriptions_go = parse_dataset('datasets/subscriptions_go.csv')
# Out:
#   subscription_type  minute_price  start_ride_price  subscription_fee
# 0              free             8                50                 0
# 1             ultra             6                 0               199
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   subscription_type  2 non-null      object
#  1   minute_price       2 non-null      int64
#  2   start_ride_price   2 non-null      int64
#  3   subscription_fee   2 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 196.0+ bytes
# None
# Процент пропусков
# subscription_type    0.0
# minute_price         0.0
# start_ride_price     0.0
# subscription_fee     0.0
# dtype: float64

# %% [markdown]
# **Вывод:**
#
# Пропусков в таблицах не обнаружено.
#
# Неправильные типы данных:
# * в датасетах user_go и subscriptions_go
#     * тип подписки `subscription_type` можно изменить на True/False - это сэкономит ресурсы.
#
# Выбросы и аномалии:
# * user_go:
#     * Возраст `age` имеет аномалию в виде несовершеннолетних.
# * rides_go:
#     * Продолжительность сессии `duration` имеет аномальные значения - 0.5 минуты.

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />  С дубликатами мы работаем на этапе предобработки, не стоит перегружать первый раздел: загрузили, проверили корректность загрузки, составили вывод, все остальное во втором разделе

# %% [markdown]
# ### 2. Предобработка данных

# %% [markdown]
# #### 2.1 Удаление дубликатов

# %%
print('Количество дубликатов в таблице user_go:', user_go.duplicated().sum())
print('Количество дубликатов в таблице rides_go', rides_go.duplicated().sum())
# Out:
# Количество дубликатов в таблице user_go: 31
# Количество дубликатов в таблице rides_go 0

# %%
user_go.drop_duplicates(subset=['user_id'], inplace=True)
print('Количество дубликатов в таблице user_go:', user_go.duplicated().sum())
# Out:
# Количество дубликатов в таблице user_go: 0

# %% [markdown]
# Найдены и удалены дубликаты в таблице user_go

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Проверка на поиск дубликатов выполнена, молодец

# %% [markdown]
# #### 2.2 Изменение типов данных

# %%
user_go['subscription_type'] = np.where(user_go['subscription_type'] == 'ultra', True, False)
subscriptions_go['subscription_type'] = np.where(subscriptions_go['subscription_type'] == 'ultra', True, False)

user_go.rename({'subscription_type':'is_subscription'}, axis=1, inplace=True)
subscriptions_go.rename({'subscription_type':'is_subscription'}, axis=1, inplace=True)

rides_go['date'] = pd.to_datetime(rides_go['date'], format='%Y-%m-%d')

# %% [markdown]
# #### 2.3 Добавления вспомогающего столбца

# %%
rides_go['month'] = rides_go['date'].dt.month

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит проверить — за какой период (год или несколько лет) у нас собраны данные

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Добавил проверку в 1 пункте

# %% [markdown]
# **Вывод:**
#
# Явные дубликаты удалены, типы данных изменены. С точки зрения хранения, подходящий тип данных оптимизирует место в памяти. В датафреймах user_go и subscriptions_go подписка была переведена в тип данных boolean (логический). Также в столбцах были изменены названия для визуального понимания, что перед нами столбец из логических значений. В таблицу rides_go был добавлен столбец month с нумерацией месяца.

# %% [markdown]
# ### 3. Исследовательский анализ данных

# %%
plt.figure(figsize=(6, 3))

user_go_count_city = (user_go['city']
 .value_counts(ascending=False)
)
user_go_count_city.plot(kind='bar')

plt.grid()
plt.title('Частота встречаемости городов')
plt.xticks(rotation=90)
plt.xlabel('Город')
plt.ylabel('Количество')

plt.show()

# %%
print('Количество городов в процентном соотношении')
round(user_go_count_city / user_go_count_city.sum() * 100, 2)
# Out:
# Количество городов в процентном соотношении
# city
# Пятигорск         14.28
# Екатеринбург      13.30
# Ростов-на-Дону    12.91
# Краснодар         12.58
# Сочи              12.32
# Омск              11.93
# Тюмень            11.73
# Москва            10.95
# Name: count, dtype: float64

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Все надписи для графиков стоит оформлять на языке выполнения проекта

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Молодец, построен график с барами,  добавлен  вывод
#
# Стоит развернуть график в горизонтальные бары, если надписи оси Х не умещаются в горизонтальном виде

# %% [markdown]
# Разница пользователей из разных городов незначительная. Чаще всего сервисом пользуются в Пятигорске (14.28%), реже - в Москве (10.95%)

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Можно указать на сколько %-ов отличается кол-во пользователей в разных городах, стоит ли говорить о такой разнице?

# %%
plt.figure(figsize=(4, 3))

(user_go['is_subscription']
 .value_counts()
 .plot(kind='pie',
       autopct='%1.1f%%',
       wedgeprops={'lw':1, 'ls':'--','edgecolor':"black"},
       labels=['Без подписки', 'С подпиской'])
)

plt.title('Соотношение пользователей с подпиской и без подписки')
plt.ylabel('')

plt.show()

# %% [markdown]
# Пользователей без подписки - 835, что почти на 20% больше, чем с подпиской - 699.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Можно использовать круговую диаграмму для отображения разности в доле клиентов, у нас всего две категории

# %%
plt.figure(figsize=(12, 3))
plt.suptitle('Возраст пользователей')

plt.subplot(1, 2, 1)
plt.title('Без обработки')
plt.xlabel('years')
plt.ylabel('count')
user_go['age'].hist(bins=90)

user_go.query('age >= 18', inplace=True)

plt.subplot(1, 2, 2)
plt.title('Совершеннолетние')
plt.xlabel('years')
plt.ylabel('count')
user_go['age'].hist(bins=90)

plt.show()

# %% [markdown]
# Возраст пользователей распределен около нормального распределения. Несовершеннолетние пользователи были убраны из выборки, по случаю законодательства РФ - с 1 марта 2023 года аренда самокатов осуществляется только лицами достигшими совершеннолетия.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера </b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Молодец, верно подмечено

# %%
plt.figure(figsize=(6, 4))

plt.boxplot(rides_go['duration'],
            vert=False) 
plt.title('Длительность сессии')
plt.show()

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
# <font size="3", color = "black">
# <br />Стоит развернуть диаграмму размаха в горизонтальный вид

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Так как моя версия matplotlib 3.9.2 и она не поддерживает параметр orientation, появился вопрос. Работа происходит в юпитере, в нем можно устанавливать библиотеки, он является неким виртуальным окружением?

# %%
rides_go.query('duration < 1')['distance'].describe()
# Out:
# count      95.000000
# mean     5113.176549
# std       658.254104
# min      4030.308008
# 25%      4611.510820
# 50%      5052.769411
# 75%      5488.459099
# max      7211.007745
# Name: distance, dtype: float64

# %%
IQR = rides_go['duration'].quantile(q=0.75) - rides_go['duration'].quantile(q=0.25)
quan3_iqr = rides_go['duration'].quantile(q=0.75) + 1.5*IQR

rides_go.query('duration > @quan3_iqr')['distance'].describe()
# Out:
# count      82.000000
# mean     4476.718008
# std       517.744755
# min      3497.968627
# 25%      4140.603539
# 50%      4420.872426
# 75%      4799.849483
# max      6436.625605
# Name: distance, dtype: float64

# %% [markdown]
# Среди продолжительных поездок, которые зафиксированы как выбросы, аномальных дистанций нет. Вероятнее всего, шеринг самокатов также используется в туристических целях. Среди коротких поездок, менее одной минуты, наблюдаются дистанции от 4 до 7.2 км, что точно является аномалией.

# %%
plt.scatter(rides_go['distance'], rides_go['duration'], alpha=0.2)

plt.title('Корреляция дистанции и длительности поездок')
plt.xlabel('Дистанция')
plt.ylabel('Время поездки')
plt.show()

# %% [markdown]
# Виден выброс с дистанцией более 4 км. и временем поездки равной 30 секундам. Также, на графике корреляции можем наблюдать аномально долгие по времени и короткие по дистанции поездки.

# %%
# check
rides_go[['duration', 'distance']].sum().to_frame().style.format("{:,.0f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_9f808">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9f808_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9f808_level0_row0" class="row_heading level0 row0" >duration</th>
#       <td id="T_9f808_row0_col0" class="data row0 col0" >321,701</td>
#     </tr>
#     <tr>
#       <th id="T_9f808_level0_row1" class="row_heading level0 row1" >distance</th>
#       <td id="T_9f808_row1_col0" class="data row1 col0" >55,480,684</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Функция для замены аномалий медианным значением категории.
def cetegories_median(df, clm1, clm2, n):
    series_filter = df.query(f'{clm1} == {n}')[clm2].astype(int)
    
    a = series_filter.min()
    b = series_filter.max()
    step = int(np.ceil((b-a)/10))
    
    for i in range(a, b, step):
        df.loc[(df[clm1] == n) & (df[clm2] > i) & (df[clm2] < i+step), clm1] = \
        df.query(f'(@i < {clm2} < @i+@step) & ({clm1} != {n})')[clm1].median()

    return df

# %%
rides_go.pipe(cetegories_median, 'duration', 'distance', 0.5).query('duration < 1')['user_id'].count()
# Out:
# 0

# %% [markdown]
# Аномально быстрые по времени поездки были заменены на медианные значения по категориям дистанций.

# %%
rides_go.query('((distance/25000*60) > duration)')
# Out:
#        user_id     distance   duration       date  month
# 9099       894  5507.980168  13.015960 2021-11-30     11
# 14241     1261  5170.970011  12.341940 2021-01-29      1
# 14310     1265  6088.051913  14.595969 2021-09-22      9
# 15332     1341  5215.548311  12.431097 2021-08-29      8

# %% [markdown]
# В сводной таблице предствалены поездки со скоростью, превыщающей ограничение. Так как скорость не превышает 25.4 км/ч., то можем считать эти данные в пределах нормы.

# %%
plt.figure(figsize=(12, 4))
plt.suptitle('Графики без аномальных поездок')

plt.subplot(1, 2, 1)
plt.boxplot(rides_go['duration'],
            vert=False)
plt.title('Ящик с усами длительности поездки')

plt.subplot(1, 2, 2)
plt.scatter(rides_go['distance'], rides_go['duration'], alpha=0.2)
plt.title('Корреляция дистанции и длительности поездок')
plt.xlabel('Дистанция')
plt.ylabel('Время поездки')

plt.show()

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Для красоты («продаваемости») всего проекта не стоит выходить за видимую ширину тетради юпитер ноутбука, коллеги ценят удобство прочтения кода. Широкие строки кода рекомендуется — делить <a href="https://qastack.ru/programming/53162/how-can-i-do-a-line-break-line-continuation-in-python">Перенос длинных строк кода</a>.
#
# </div>

# %% [markdown]
# **Вывод:**
#
# Севис шеринга самокатов GoFast ориентирован на города: Тюмень, Омск, Москва, Ростов-на-Дону, Краснодар, Пятигорск, Екатеринбург, Сочи. В разных городах сервисом пользуются примерно в одинаковых пропорциях. Пользователей без подписки на 20% больше, чем с подпиской ultra. Несовершеннолетние пользователи были удалены фильтром.

# %%
# check
rides_go[['duration', 'distance']].sum().to_frame().style.format("{:,.0f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_30a06">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_30a06_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_30a06_level0_row0" class="row_heading level0 row0" >duration</th>
#       <td id="T_30a06_row0_col0" class="data row0 col0" >323,873</td>
#     </tr>
#     <tr>
#       <th id="T_30a06_level0_row1" class="row_heading level0 row1" >distance</th>
#       <td id="T_30a06_row1_col0" class="data row1 col0" >55,480,684</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Скажи пожалуйста, почему ты считаешь подобный способ замены условных аномалий корректным?
#
# Если предположить, что блок определения расстояния мог сбоить
#
# У нас была выборка с такой формой
#
# ![image.png](attachment:image.png)
#
# стала с такой
#
# ![image-2.png](attachment:image-2.png)
#
#         321,701 → 312,184
#
# и мы потеряли данные почти о 9 500 минутах

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Условно, При дистанции в 0 метров время сессии занимает 15 минут. Я принял считать такие данные аномальными. Сейчас понимаю, что я 'стандартизировал' и избавлялся от нелинейности, что плохо.

# %% [markdown]
# ### 4. Объединение данных

# %%
print('Количество уникальных пользователей в датафрейме user_go:', user_go['user_id'].nunique())
print('Количество уникальных пользователей в датафрейме rides_go:', rides_go['user_id'].nunique())
# Out:
# Количество уникальных пользователей в датафрейме user_go: 1455
# Количество уникальных пользователей в датафрейме rides_go: 1534

# %%
np.setdiff1d(rides_go['user_id'].unique(), user_go['user_id'].unique())
# Out:
# array([  21,   34,   35,   49,   67,   76,   84,  146,  152,  164,  176,
#         183,  184,  233,  236,  238,  246,  269,  295,  306,  315,  322,
#         345,  350,  353,  393,  412,  449,  455,  457,  467,  476,  479,
#         508,  521,  526,  548,  554,  638,  665,  695,  716,  728,  754,
#         780,  811,  887,  902,  934,  972,  981, 1022, 1028, 1049, 1054,
#        1086, 1112, 1113, 1133, 1162, 1187, 1205, 1209, 1220, 1242, 1248,
#        1250, 1269, 1272, 1283, 1334, 1378, 1379, 1464, 1475, 1476, 1477,
#        1488, 1516])

# %% [markdown]
# В таблице `rides_go` на 79 пользователей больше. Это связано с тем, что ранее несовершеннолетние пользователи были убраны фильтром.

# %%
data = (user_go.sort_values(by='user_id', ascending=True)
        .merge(rides_go.sort_values(by=['user_id', 'date'], ascending=True),
               on='user_id',
               how='left')
        .merge(subscriptions_go,
               on='is_subscription',
               how='left')
       )

data.head(15)
# Out:
#     user_id       name  age    city  is_subscription     distance   duration  \
# 0         1       Кира   22  Тюмень             True  4409.919140  25.599769
# 1         1       Кира   22  Тюмень             True  2617.592153  15.816871
# 2         1       Кира   22  Тюмень             True   754.159807   6.232113
# 3         1       Кира   22  Тюмень             True  2694.783254  18.511000
# 4         1       Кира   22  Тюмень             True  4028.687306  26.265803
# 5         1       Кира   22  Тюмень             True  2770.890808  16.650138
# 6         1       Кира   22  Тюмень             True  3039.020292  14.927879
# 7         1       Кира   22  Тюмень             True  2842.118050  23.117468
# 8         1       Кира   22  Тюмень             True  3412.690668  15.238072
# 9         1       Кира   22  Тюмень             True   748.690645  15.041884
# 10        1       Кира   22  Тюмень             True  4031.020195  17.674448
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> На этих данных — объединение прошло по плану.
#
#
#
# Обрати внимание на параметры, которые пандас выставляет по умолчанию при merge (для справки в join такая же «засада» по характеру, но другая по исполнению)
#
# Использование параметров по умолчанию может привести к потере данных при объединении
#
#
# [Примеры объединения таблиц, merge](https://pandas.pydata.org/pandas-docs/version/1.5/reference/api/pandas.DataFrame.merge.html?highlight=merge#pandas.DataFrame.merge)
#
# [Примеры объединения таблиц, join](https://pandas.pydata.org/pandas-docs/version/1.5/reference/api/pandas.DataFrame.join.html?highlight=join#pandas.DataFrame.join)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17092 entries, 0 to 17091
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   user_id           17092 non-null  int64
#  1   name              17092 non-null  object
#  2   age               17092 non-null  int64
#  3   city              17092 non-null  object
#  4   is_subscription   17092 non-null  bool
#  5   distance          17092 non-null  float64
#  6   duration          17092 non-null  float64
#  7   date              17092 non-null  datetime64[ns]
#  8   month             17092 non-null  int32
#  9   minute_price      17092 non-null  int64
#  10  start_ride_price  17092 non-null  int64
#  11  subscription_fee  17092 non-null  int64
# dtypes: bool(1), datetime64[ns](1), float64(2), int32(1), int64(5), object(2)
# memory usage: 1.4+ MB

# %% [markdown]
# Чтобы избежать возможных неприятностей после склейки, датафрейм `user_go` был отсортирован по увеличению столбца 'user_id'. Аналогично с датафреймом `rides_go`, дополнительно для удобства уникальные id были отсортированы по датам. Обьединение таблиц происходило по датафрейму `user_go`, поэтому в новой таблице `data` данные об несовершеннолетних пользователей отсутвуют, пропуски в данных не появились.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />  Стоит добавить минивывод после объединения таблиц, сохранились ли все данные, не появились ли пропуски в данных

# %%
data_ultra = data.query('is_subscription == True')

data_ultra.sample(5)
# Out:
#       user_id     name  age          city  is_subscription     distance  \
# 585        70     Вера   32          Омск             True  3378.415932
# 1166      134  Людмила   28        Москва             True  2918.105132
# 4072      473    Самир   33  Екатеринбург             True  3244.925272
# 1188      137     Нина   24        Москва             True  3569.118456
# 1263      145    Данил   32          Сочи             True  3005.986323
#
#        duration       date  month  minute_price  start_ride_price  \
# 585   12.446040 2021-02-20      2             6                 0
# 1166  23.299195 2021-08-12      8             6                 0
# 4072  12.112313 2021-02-16      2             6                 0
# 1188  12.384383 2021-05-20      5             6                 0
# 1263  24.029932 2021-12-17     12             6                 0
#
#       subscription_fee
# 585                199
# 1166               199
# 4072               199
# 1188               199
# ...

# %%
data_free = data.query('is_subscription == False')

data_free.sample(5)
# Out:
#        user_id     name  age          city  is_subscription     distance  \
# 16316     1478   Роберт   21     Пятигорск            False  1992.627458
# 11692     1128  Георгий   27     Краснодар            False   899.756406
# 8301       871   Михаил   21  Екатеринбург            False  3746.705278
# 10249     1015   Кирилл   26  Екатеринбург            False  2492.063062
# 14258     1323     Алла   22        Тюмень            False  2199.232008
#
#         duration       date  month  minute_price  start_ride_price  \
# 16316   6.981569 2021-02-07      2             8                50
# 11692   6.999188 2021-12-10     12             8                50
# 8301   23.986821 2021-10-25     10             8                50
# 10249  16.155993 2021-08-20      8             8                50
# 14258  15.330773 2021-04-02      4             8                50
#
#        subscription_fee
# 16316                 0
# 11692                 0
# 8301                  0
# ...

# %%
def show_ultra_free(df, flag):
    plt.figure(figsize=(12, 4))
    plt.suptitle(f'Пользователи {'с подпиской' if flag else 'без подписки'}', weight='heavy')
    
    plt.subplot(1, 3, 1)
    plt.title('Гистограмма дистанций')
    plt.hist(df['distance'], bins=50)
    plt.xlabel('Дистанция')
    plt.ylabel('Количество', fontsize=14)
    plt.grid()
    
    plt.subplot(1, 3, 2)
    plt.title('Гистограмма продолжительности сессии')
    plt.hist(df['duration'], bins=70)
    plt.xlabel('Длительность сессии')
    plt.grid()
    
    plt.subplot(1, 3, 3)
    plt.title('Корреляция')
    plt.scatter(df['distance'], df['duration'], alpha=0.15)
    plt.xlabel('Дистанция')
    plt.ylabel('Время поездки')
    plt.grid()
    
    plt.show()


show_ultra_free(data_ultra, True)
show_ultra_free(data_free, False)

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит совместить гистограммы на одном виде, по две гистограммы для каждого параметра, чтобы появилась возможность визуально сравнить параметры у двух разных групп клиентов

# %%
(data_free[['distance', 'duration']].describe()
 
 .join(data_ultra[['distance', 'duration']].describe(),
       lsuffix='_free',
       rsuffix='_ultra')
 
 .iloc[:, [0, 2, 1, 3]]
)
# Out:
#        distance_free  distance_ultra  duration_free  duration_ultra
# count   11008.000000     6084.000000   11008.000000     6084.000000
# mean     3048.223377     3112.506006      17.568846       18.516549
# std      1245.709759      839.139350       6.159858        5.573458
# min         0.855683      244.210438       2.035632        3.760353
# 25%      2369.568927     2785.359959      13.129161       14.501104
# 50%      3115.788825     3147.798444      17.443131       18.171178
# 75%      3908.284417     3560.574425      21.747017       21.847630
# max      7211.007745     5699.769662      34.948498       40.823963

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит  добавить сравнение статистик у двух групп пользователей при помощи метода
#
#         .describe()

# %%
plt.figure(figsize=(10, 4))
plt.title('Гистограмма скорости')

plt.xlabel('Скорость')
plt.ylabel('Количество')


def hist_speed(df, flag):
    (df
     .apply(lambda x: (x['distance']*60)/(x['duration']*1000), axis=1)
     .hist(bins=50, label='ultra' if flag else 'free')
    )
    plt.legend(title='Подписка', edgecolor='black')


hist_speed(data_free, False)
hist_speed(data_ultra, True)

plt.show()

# %% [markdown]
# **Вывод:**
#
# Пользователи с подпиской и без имеют похожие распределения. Пользователи с подпиской чаще арендуют самокат для дистанции в 3 км, когда пользователи без подписки для 2.5 - 3.5 км. Можно заметить, что пользователи без подписки арендовывают самокат на более большие дистанции и на менее короткие сессии, следовательно их скорость должна быть выше. Было проведено дописследование, пользователи с подпиской не разгоняются более 22 км/ч, когда пользователи без могут ехать до 25 км/ч.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Молодец — интересное дополнение

# %% [markdown]
# ### 5. Подсчёт выручки

# %%
df_agg = (pd.merge(data.pivot_table(index=['user_id', 'month'],
                                    values=['distance', 'duration'],
                                    aggfunc=['sum', 'count'])
         .drop(('count', 'distance'), axis=1),
         
        (data.assign(duration_ceil=lambda x: np.ceil(x['duration']))
                     .pivot_table(index=['user_id', 'month'],
                                  values=['duration_ceil',
                                          'minute_price',
                                          'start_ride_price',
                                          'subscription_fee'],
                                  aggfunc=['sum', 'mean'])
                     .drop([('sum', 'minute_price'),
                            ('sum', 'start_ride_price'),
                            ('sum', 'subscription_fee'),
                            ('mean', 'duration_ceil')], axis=1)),
                   
         on=('user_id', 'month')
                   
        ).assign(income=lambda x: (x[('sum', 'duration_ceil')] * x[('mean', 'minute_price')]) \
                 + (x[('mean', 'start_ride_price')] * x[('count', 'duration')]) + x[('mean', 'subscription_fee')])
          
         .drop([('sum', 'duration_ceil'),
                ('mean', 'minute_price'),
                ('mean', 'start_ride_price')], axis=1)
)

df_agg.columns = ['sum_distance', 'sum_duration', 'num_trips', 'is_subscription', 'income']
df_agg = df_agg.assign(is_subscription=lambda x: x['is_subscription'] == 199)

df_agg
# Out:
#                sum_distance  sum_duration  num_trips  is_subscription  income
# user_id month
# 1       1       7027.511294     41.416640          2             True   451.0
#         4        754.159807      6.232113          1             True   241.0
#         8       6723.470560     44.776802          2             True   475.0
#         10      5809.911100     31.578017          2             True   391.0
#         11      7003.499363     53.397424          3             True   535.0
# ...                     ...           ...        ...              ...     ...
# 1534    6       3409.468534     24.812678          2            False   308.0
#         8       7622.453034     47.205960          2            False   484.0
#         9       4928.173852     22.560373          1            False   234.0
#         11     13350.015305     76.342174          4            False   824.0
#         12      2371.711192     15.893917          1            False   178.0
#
# ...

# %%
df_agg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 10730 entries, (1, 1) to (1534, 12)
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   sum_distance     10730 non-null  float64
#  1   sum_duration     10730 non-null  float64
#  2   num_trips        10730 non-null  int64
#  3   is_subscription  10730 non-null  bool
#  4   income           10730 non-null  float64
# dtypes: bool(1), float64(3), int64(1)
# memory usage: 421.3 KB

# %% [markdown]
# Пропуски после агрегации данных не обнаружены.

# %%
#check
df_agg['income'].sum()
# Out:
# 3682421.0

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Молодец — применена довольно сложная схема кода

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> В чем опасность твоего подхода — не учитываешь возможное появление пропусков
#
# Стоит проверить агрегированные данные на пропуски, перед расчетом суммы продаж

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Не совсем понимаю, зачем проверять на пропуски. При создании `data` пропусков не было обнаружено, при создании сводной таблицы, им неоткуда появляться. При агрегации откуда они могут появиться?

# %%
income_month = df_agg.pivot_table(index='month', values='income', aggfunc='sum')

print(f'Средняя выручка в месяц: {round(income_month.mean().iloc[0])}',
              f'Выручка за 2021 год: {round(income_month.sum().iloc[0])}',
              sep='\n')

income_month.plot(style='-o', legend=False)
plt.title('Выручка в месяц со всех пользователей')
plt.xlabel('Месяц')
plt.ylabel('Выручка')
plt.grid()

plt.show()
# Out:
# Средняя выручка в месяц: 306868
# Выручка за 2021 год: 3682421

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Странно, что летний период не выделяется по сравнению с остальными.

# %%
income_month.describe()
# Out:
#               income
# count      12.000000
# mean   306868.416667
# std     13808.194000
# min    275418.000000
# 25%    303648.250000
# 50%    308552.500000
# 75%    316089.500000
# max    322806.000000

# %%
def income_month_sub(is_sub):
    income_month_sub = (df_agg
                        .query('is_subscription == @is_sub')
                        .pivot_table(index='month',
                                     values='income',
                                     aggfunc=['sum', 'count']))
    income_month_sub.columns = ['income_sum', 'count']
    return (income_month_sub['income_sum'] / income_month_sub['count']), income_month_sub['income_sum'].sum()

# %%
income_month_free, income_month_free_sum = income_month_sub(False)
income_month_ultra, income_month_ultra_sum = income_month_sub(True)

income_month_free.plot(style='-o', label='free')
income_month_ultra.plot(style='-o', label='ultra')

plt.legend(title='Подписка', edgecolor='black', loc='center right')
plt.title('Сердняя выручка с пользователя в месяц')
plt.xlabel('Месяц')
plt.ylabel('Выручка')
plt.grid()

plt.show()

# %%
print(f'Средняя выручка с пользователя с подпиской: {round(income_month_ultra.mean(), 2)}',
      f'Средняя выручка с пользователя без подписки: {round(income_month_free.mean(), 2)}',
      f'Выручка за год с пользователей с подпиской: {round(income_month_ultra_sum)}',
      f'Выручка за год с пользователей без подписки: {round(income_month_free_sum)}',
      sep='\n')
# Out:
# Средняя выручка с пользователя с подпиской: 361.97
# Средняя выручка с пользователя без подписки: 330.72
# Выручка за год с пользователей с подпиской: 1540813
# Выручка за год с пользователей без подписки: 2141608

# %% [markdown]
# **Вывод:**
#
# Создан датафрейм с агрегированными данными. Он включает в себя статистику пользователей за каждый месяц, в котором была активность: преодоленная дистанция, суммарное время и количество поездок, флаг наличия подписки, выручка, которую принес пользователь. Пропуски не были выявлены.
#
# Выручка за 2021 год: 3682421 \
# Средняя выручка в месяц: 306868
#
# Средняя выручка с пользователя с подпиской: 361.97 \
# Средняя выручка с пользователя без подписки: 330.72
#
# Выручка за год с пользователей с подпиской: 1540813 \
# Выручка за год с пользователей без подписки: 2141608
#
# Февраль 2021 года оказался менее прибыльным - 275 т.р.

# %% [markdown]
# ### 6. Проверка гипотез

# %% [markdown]
# #### Гипотеза 1. Тратят ли пользователи с подпиской больше времени на поездки?
#
# Нулевая гипотеза (H0): пользователи с подпиской и без тратят в среднем равное время на поездки\
# Альтернативная гипотеза (H1): пользователи с подпиской в среднем тратят больше времени на поездки\
# Уровень статистической значимости: 5%

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ <b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br /> Из формулировок Н0 и Н1, и из вывода пропало слово среднее
#
# ![image.png](attachment:image.png)

# %%
alpha=0.05

res = st.ttest_ind(data_ultra['duration'],
             data_free['duration'],
             equal_var=False, # Выборки разных размеров.
             alternative='greater')

print('p-value:', res.pvalue)
print('Отвергаем нулевую гипотезу.') if res.pvalue < alpha else print('Нет оснований отвергать нулевую гипотезу.')
# Out:
# p-value: 7.448892807067866e-25
# Отвергаем нулевую гипотезу

# %% [markdown]
# Есть основание полагать, что пользователи с подпиской тратят больше времени на поездки. Следовательно, подписчики будут более выгодными для бизнеса. Самокаты будут меньше простаивать, так как будут больше находиться в пути. Возможно повысится спрос, в связи с уменьшением их количества на парковке.

# %% [markdown]
# #### Гипотеза 2: Можно ли сказать, что среднее расстояние, которое проезжают пользователи с подпиской за одну поездку, не превышает 3130 метров?
#
# Нулевая гипотеза (H0): Среднее расстояние, которое проезжают пользователи с подпиской за одну поездку не превышает 3130 метров\
# Альтернативная гипотеза (H1): Среднее расстояние, которое проезжают пользователи с подпиской за одну поездку больше оптимального\
# Уровень статистической значимости: 5%

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />В данном случае стоит использовать параметр alternative = 'greater'. Поскольку оптимальное расстояние по износу составляет 3130 м, значит большее расстояние приводит к повышенному износу самоката. Следовательно, имеет смысл сформулировать альтернативную гипотезу "Подписчики в среднем проезжают расстояние больше оптимального"
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Спасибо, действительно, тут следует использовать аргумент 'greater'. В таком случае, Нулевая гипотеза - меньше или равно, а альтернативная - больше.

# %%
target_value=3130
alpha=0.05

res = st.ttest_1samp(data_ultra['distance'],
                     target_value,
                     alternative='greater')

print('p-value:', res.pvalue)
if res.pvalue < alpha:
    print('Отвергаем нулевую гипотезу. Среднее расстояние явно не превышает 3130 метров.')
else:
    print('Нет оснований отвергать нулевую гипотезу.')
# Out:
# p-value: 0.9480108018181459
# Нет оснований отвергать нулевую гипотезу.

# %% [markdown]
# Статистический односторонний тест показал, что объект исследования не превышает 3130 метров. А значит, нет оснований отвергать нашу изначальную гипотезу. Следовательно самокаты не успевают износиться и можно повременить с их ремонтом или заменой.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит поправить вывод
#
#         Статистический односторонний тест показал, что объект исследования не меньше 3130 метров. А значит, наша изначальная гипотеза 'Можно ли сказать, что среднее расстояние, которое проезжают пользователи с подпиской за одну поездку, не превышает 3130 метров?' - отверглась.
#
#         Близкое к единице значение p-value не означает, что среднее расстояние равно 3130 метров. При одностороннем тесте вероятность уровня значимости приходится на одну сторону, следовательно среднее даже может быть больше.
#
#
# У тебя
#
#         Нулевая гипотеза (H0): Среднее расстояние, которое проезжают пользователи с подпиской за одну поездку равно 3130 метров
#
# и результат стат теста
#
#         p-value: 0.9999999148053914
#         Нет оснований отвергать нулевую гипотезу.

# %% [markdown]
# #### Гипотеза 3: Больше ли выручка от пользователей с подпиской, чем выручка от пользователей без подписки?
#
# Нулевая гипотеза (H0): Средняя выручка от пользователей с подпиской и без равна\
# Альтернативная гипотеза (H1): Средняя выручка от пользователей с подпиской больше, чем средняя выручка от пользователей без подписки\
# Уровень статистической значимости: 5%

# %%
alpha=0.05

res = st.ttest_ind(df_agg.query('is_subscription')['income'],
                   df_agg.query('~is_subscription')['income'],
                   equal_var=False,
                   alternative='greater')

print('p-value:', res.pvalue)

if res.pvalue < alpha:
    print('Отвергаем нулевую гипотезу.')
else:
    print('Нет оснований отвергать нулевую гипотезу.')
# Out:
# p-value: 4.46020216244253e-32
# Отвергаем нулевую гипотезу.

# %% [markdown]
# По всей видимости, пользователи с подпиской действительно приносят больше выручки. Значит, нужно предпринять стратегию по увеличению пользователей с подпиской.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# Стоит поправить все выводы, добавить акценты с точки зрения бизнеса

# %% [markdown]
# Представьте такую ситуацию:\
# техническая команда сервиса обновила сервера, с которыми взаимодействует мобильное приложение.\
# Она надеется, что из-за этого количество обращений в техподдержку значимо снизилось.\
# Некоторый файл содержит для каждого пользователя данные о количестве обращений до обновления и после него.\
# Какой тест вам понадобился бы для проверки этой гипотезы?
#
# - Для данной гипотезы, нам понадобился бы тест о равенстве средних для зависимых выборок. Так как мы будем проверять гипотезу над данными до и после их преобразования, такой тест в `scipy.stats` называется `ttest_rel`.

# %%
#H0 - среднее количество обращений после обновления сервера останется таким же
#H1 - среднее количество обращений после обновления сервера сократится

np.random.seed(1)

appeal_test_before = pd.Series(np.random.randint(0, 50, 100))
appeal_test_after = pd.Series(np.random.randint(0, 40, 100))

alpha=0.5

res = st.ttest_rel(appeal_test_before,
                   appeal_test_after,
                   alternative='greater')

if res.pvalue < alpha:
    print('Отвергаем нулевую гипотезу.')
else:
    print('Не получилось отвергнуть нулевую гипотезу. Количество обращений в техподдержку до и после обновления не изменилось')
# Out:
# Отвергаем нулевую гипотезу.

# %% [markdown]
# Обновление сервера пошло на пользу. Среднее количество обращений в техподдержку сократилось.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера </b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит  расписать полный стат тест с вымышленными выборками по всем твоим вводным. Сейчас мы не сможем ответить на вопрос заказчика
#
#          Она надеется, что из-за этого количество обращений в техподдержку значимо снизилось.
#
#
# __подсвечу, что для стат теста важен порядок выборок, которые мы подаем на расчет__

# %% [markdown]
# **Вывод:**
# - Тратят ли пользователи с подпиской больше времени на поездки?
#     - Есть основание пологать, что пользователи с подпиской тратят больше времени на поездки.
# - Можно ли сказать, что среднее расстояние, которое проезжают пользователи с подпиской за одну поездку, не превышает 3130 метров?
#     - Нет оснований отвергать нашу гипотезу.
# - Больше ли выручка от пользователей с подпиской, чем выручка от пользователей без подписки?
#     - Гипотеза не была отвергнута. Вероятно пользователи с подпиской приносят больше выручки.

# %% [markdown]
# ### 7. Общий вывод работы

# %% [markdown]
# Аномальные значения продолжительности сессии были заменены на медианные значения по категории дистанции. Несовершеннолетние были убраны из датафрема, поскольку они нерентабельны. Явные дубликаты удалены, типы данных изменены на соответсвующие, добавлен столбец с нумерацией месяца.
#
# Сервисом шеринга самокатов GoFast в разных городах пользуются в около равных пропорциях. Пользователей с подпиской на 20% меньше, они тратят больше времени на поездки, пренебрегая высокую скорость. Пользователи с подпиской в среднем имеют большую продолжительность сессии. Среднее расстояние пользователей с подпиской не превышает расстояние износа самоката. Компания в среднем получает больше выручки с пользователей с подпиской, поэтому сервису будет выгодно привлечь аудиторию к покупке или продлению подписки.
#
# Выручка за 2021 год: 3682421 \
# Средняя выручка в месяц: 306868 \
# Средняя выручка с пользователя с подпиской: 361.97 \
# Средняя выручка с пользователя без подписки: 330.72 \
# Выручка за год с пользователей с подпиской: 1540813 \
# Выручка за год с пользователей без подписки: 2141608

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера  </b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит добавить или поправить
#
# + выводы по гипотезам
# + сравнение показателей суммарной годовой выручки для каждого тарифа и среднемесячной выручки для среднего пользователя, также для каждого тарифа
#  + условно, 1 млн. руб. за год мы заработали на пользователях с подпиской и 2 млн. руб. на пользователях без подписки
#  + условно, 300 руб. в среднем в месяц нам приносит один пользователь с подпиской и 200 рублей пользователь без подписки

# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Ты выполнил практически все пункты проекта, молодец! Проведен значительный объем исследования деятельности компании
#
# Критические ❌ комментарии:
#
#  + поправить графики
#  + добавить статистики в промежуточные выводы
#  + прочие
#  + поправить выводы и стат тест
#
# Стоит обратить внимание на ⚠️ комментарии...
#
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5", color= "seagreen"><b>Жду твой проект и твои комментарии 🤝</b></font><br />

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Ринат, благодарю вас за ревью! Видно, отнеслись с должным вниманием к моей работе. Было очень приятно читать комментарии, спасибо. Жду обратного ответа, готов еще что-то поисправлять!
#
# С гипотезами, по всей видимости, у меня сложности. Начну с Савельева.

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# [Подробное руководство по группировке и агрегированию с помощью pandas](https://dfedorov.spb.ru/pandas/%D0%9F%D0%BE%D0%B4%D1%80%D0%BE%D0%B1%D0%BD%D0%BE%D0%B5%20%D1%80%D1%83%D0%BA%D0%BE%D0%B2%D0%BE%D0%B4%D1%81%D1%82%D0%B2%D0%BE%20%D0%BF%D0%BE%20%D0%B3%D1%80%D1%83%D0%BF%D0%BF%D0%B8%D1%80%D0%BE%D0%B2%D0%BA%D0%B5%20%D0%B8%20%D0%B0%D0%B3%D1%80%D0%B5%D0%B3%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D1%8E%20%D1%81%20%D0%BF%D0%BE%D0%BC%D0%BE%D1%89%D1%8C%D1%8E%20pandas.html)
#
# [Примеры объединения таблиц, общая справка](https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html)
#
# [Примеры объединения таблиц, Федоров Д.](https://dfedorov.spb.ru/pandas/08.%20%D0%9A%D0%B0%D0%BA%20%D0%BE%D0%B1%D1%8A%D0%B5%D0%B4%D0%B8%D0%BD%D0%B8%D1%82%D1%8C%20%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D0%B5%20%D0%B8%D0%B7%20%D0%BD%D0%B5%D1%81%D0%BA%D0%BE%D0%BB%D1%8C%D0%BA%D0%B8%D1%85%20%D1%82%D0%B0%D0%B1%D0%BB%D0%B8%D1%86_.html?ysclid=lklv5hyic8790467123)
#
#
#
# [Искусство статистики](https://www.mann-ivanov-ferber.ru/books/iskusstvo-statistiki/)
#
#
# В помощь — как реализовать интерактивный план проекта вручную, смотри по <a href="https://stackoverflow.com/questions/49535664/how-to-hyperlink-in-a-jupyter-notebook/49717704">ссылке</a>
#
# пара ссылок и по разделам проекта можно будет переходить без пролистывания всего кода, особенно актуально на проектах длина которых >  10 страниц (и там где не установлен плагин TOC)
#
#
# [Прикладной анализ данных в социальных науках](https://education.yandex.ru/handbook/data-analysis)
